# %% [markdown]
# Gráfico de líneas

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

plt.plot(x, y)

plt.xlabel('Eje X')
plt.ylabel('Eje Y')
plt.title('Gráfico de líneas simple')
plt.plot(x, y, color='red')
plt.show()

# %% [markdown]
# Grafico de líneas con diseño

# %%
import matplotlib.pyplot as plt

meses = ['Enero', 'Febrero', 'Marzo', 'Abril', 'Mayo']
ventas = [1500, 1800, 1200, 1700, 2100]
plt.plot(meses, ventas, color='blue', marker='o', linestyle='--')
plt.xlabel('Meses')
plt.ylabel('Ventas en USD')
plt.title('Ventas Mensuales')
plt.show()

# %% [markdown]
# Grafica de líneas

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 7, 11]
plt.plot(x,y, color='blue', marker='*', linestyle='--')
plt.plot(x, y)
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Gráfica de línea')
plt.show()

# %% [markdown]
# ejemplo de datos: estados emocionales de animales

# %%
import matplotlib.pyplot as plt
import numpy as np

gato = ["aburrido", "feliz", "aburrido", "aburrido", "feliz", "aburrido"]
perro = ["feliz", "feliz", "feliz", "feliz", "aburrido", "aburrido"]
actividad = ["peinar", "beber", "alimentar", "dormir", "jugar", "lavar"]
fig, ax = plt.subplots()
ax.plot(actividad, perro, label="perro")
ax.plot(actividad, gato, label="gato")
ax.legend()
plt.show()

# %% [markdown]
# Lineas con multiples series

# %%
import matplotlib.pyplot as plt
import numpy as np
x = [1, 2, 3, 4, 5]
y1 = [1, 4, 9, 16, 25]
y2 = [2, 4, 6, 8, 10]
plt.plot(x, y1, label='Serie 1')
plt.plot(x, y2, label='Serie 2')
plt.legend()
plt.title('Gráfico de líneas con múltiples series')
plt.show()

# %% [markdown]
# Gráfico de barras

# %%
import matplotlib.pyplot as plt

productos = ['Producto A', 'Producto B', 'Producto C']
cantidad_vendida = [50, 75, 100]
plt.bar(productos, cantidad_vendida, color='green')
plt.xlabel('Productos')
plt.ylabel('Cantidad Vendida')
plt.title('Ventas por Producto')
plt.show()

# %% [markdown]
# Grafico de dispersion

# %%
import matplotlib.pyplot as plt

horas_estudio = [1, 2, 3, 4, 5]
puntuaciones = [50, 60, 70, 80, 90]
plt.scatter(horas_estudio, puntuaciones, color='red')
plt.xlabel('Horas de Estudio')
plt.ylabel('Puntuación en el Examen')
plt.title('Relación entre Estudio y Resultados')
plt.show()

# %% [markdown]
# Grafico de dispersion personalizado

# %%
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(19680801)

data = {'a': np.arange(50),
        'c': np.random.randint(0, 50, 50),
        'd': np.random.randn(50)}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

fig, ax = plt.subplots()
ax.scatter('a', 'b', c='c', s='d', data=data)
ax.set(xlabel='entry a', ylabel='entry b')
plt.show()

# %% [markdown]
# Otros graficos

# %%
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(19680801)

def imagen_degradado(ax, direccion=0.3, rango_cmap=(0, 1), extent=None, **kwargs):
    """
    Dibuja una imagen con degradado basada en un mapa de colores.

    Parámetros
    ----------
    ax : Axes
        Los ejes en los que se dibujará.
    direccion : float
        La dirección del degradado. Este número está en el rango de 0 (=vertical) a 1 (=horizontal).
    rango_cmap : float, float
        La fracción (cmin, cmax) del mapa de colores que se utilizará para el degradado,
        donde el mapa de colores completo está en (0, 1).
    extent : tuple or None
        Los límites del área en la que dibujar la imagen.
    **kwargs
        Otros parámetros se pasan a `.Axes.imshow()`. En particular, *cmap*, *extent* y *transform* pueden ser útiles.
    """
    phi = direccion * np.pi / 2
    v = np.array([np.cos(phi), np.sin(phi)])
    X = np.array([[v @ [1, 0], v @ [1, 1]],
                  [v @ [0, 0], v @ [0, 1]]])
    a, b = rango_cmap
    X = a + (b - a) / X.max() * X
    im = ax.imshow(X, interpolation='bicubic', clim=(0, 1),
                   aspect='auto', extent=extent, **kwargs)
    return im

def barra_degradado(ax, x, y, ancho=0.5, fondo=0):
  for izquierda, arriba in zip(x, y):
    derecha = izquierda + ancho
    imagen_degradado(ax, extent=(izquierda, derecha, fondo, arriba),
                         cmap=plt.cm.Blues_r, rango_cmap=(0, 0.8))

fig, ax = plt.subplots()
ax.set(xlim=(0, 10), ylim=(0, 1))

imagen_degradado(ax, direccion=1, extent=(0, 1, 0, 1), transform=ax.transAxes,
                 cmap=plt.cm.RdYlGn, rango_cmap=(0.2, 0.8), alpha=0.5)

N = 10
x = np.arange(N) + 0.15
y = np.random.rand(N)
barra_degradado(ax, x, y, ancho=0.7)
plt.show()

# %% [markdown]
# Diagrama de tallo

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0.1, 2 * np.pi, 41)
y = np.exp(np.sin(x))

plt.stem(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Gráfico de tallos')
plt.show()

# %% [markdown]
# HISTOGRAMAS

# %%
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(19680801)

n_bins = 10
x = np.random.randn(1000, 3)

fig, ((ax0, ax1), (ax2, ax3)) = plt.subplots(nrows=2, ncols=2)

colors = ['red', 'tan', 'lime']
ax0.hist(x, n_bins, density=True, histtype='bar', color=colors, label=colors)
ax0.legend(prop={'size': 10})
ax0.set_title('bars with legend')
ax1.hist(x, n_bins, density=True, histtype='bar', stacked=True)
ax1.set_title('stacked bar')
ax2.hist(x, n_bins, histtype='step', stacked=True, fill=False)
ax2.set_title('stack step (unfilled)')

x_multi = [np.random.randn(n) for n in [10000, 5000, 2000]]
ax3.hist(x_multi, n_bins, histtype='bar')
ax3.set_title('different sample sizes')

fig.tight_layout()
plt.show()

# %% [markdown]
# SEABORD

# %%
import seaborn as sns
#from sklearn.datasets import load_iris
flights = sns.load_dataset("flights")
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %% [markdown]
# Gráfico de líneas

# %%
import seaborn as sns

flights = sns.load_dataset("flights")
flights.head()
may_flights = flights.query("month == 'May'")
sns.lineplot(data=may_flights, x="year", y="passengers")
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %% [markdown]
# Gráfico de dispersión con diseño.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="whitegrid")
datos = sns.load_dataset("tips")

sns.scatterplot(x="total_bill", y="tip", data=datos, color="blue", s=100)
plt.title('Relación entre la cuenta total y la propina', fontsize=14)
plt.xlabel('Cuenta total (USD)', fontsize=12)
plt.ylabel('Propina (USD)', fontsize=12)
plt.show()

# %% [markdown]
# Gráfico de dispersión con 3 variables y línea de tendencia

# %%
import seaborn as sns
import matplotlib.pyplot as plt

datos = sns.load_dataset("tips")

sns.scatterplot(x='total_bill', y='tip', size='size', data=datos, hue='size', palette="cool", sizes=(20, 200))
sns.regplot(x='total_bill', y='tip', data=datos, scatter=False, color='red')

plt.title('Relación entre cuenta total, propina y tamaño del grupo')
plt.xlabel('Cuenta total (USD)')
plt.ylabel('Propina (USD)')
plt.show()

# %% [markdown]
# Grafico de Barras con libreria Seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="whitegrid")
datos = sns.load_dataset("titanic")

sns.barplot(x="class", y="fare", data=datos, palette="coolwarm")
plt.title('Promedio de tarifa por clase', fontsize=14)
plt.xlabel('Clase de pasajero', fontsize=12)
plt.ylabel('Tarifa promedio (USD)', fontsize=12)
plt.show()
# Out:
# <ipython-input-23-15a97c6db9c1>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="class", y="fare", data=datos, palette="coolwarm")

# %% [markdown]
# Gráfico de distribución

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="darkgrid")
datos = sns.load_dataset("iris")

sns.histplot(datos['sepal_length'], kde=True, color="purple")
plt.title('Distribución de la longitud del sépalo', fontsize=14)
plt.xlabel('Longitud del sépalo (cm)', fontsize=12)
plt.ylabel('Frecuencia', fontsize=12)
plt.show()

# %% [markdown]
# Gráfico de caja

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="whitegrid")
datos = sns.load_dataset("tips")

sns.boxplot(x="day", y="total_bill", data=datos, palette="Set2")
plt.title('Distribución de la cuenta total por día', fontsize=14)
plt.xlabel('Día de la semana', fontsize=12)
plt.ylabel('Cuenta total (USD)', fontsize=12)
plt.show()
# Out:
# <ipython-input-25-6e3d827744a0>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="day", y="total_bill", data=datos, palette="Set2")

# %% [markdown]
# Mapa de calor

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="white")
datos = sns.load_dataset("flights")
tabla_pivote = datos.pivot(index="month", columns="year", values="passengers")
sns.heatmap(tabla_pivote, annot=True, fmt="d", cmap="YlOrRd", linewidths=0.5)
plt.title('Número de pasajeros por mes y año', fontsize=14)
plt.xlabel('Año', fontsize=12)
plt.ylabel('Mes', fontsize=12)
plt.show()
