# %%
import matplotlib.pyplot as plt
asignaturas = ["Matemáticas", "Ciencias", "Historia", "Inglés", "Arte"]
calificaciones = [85, 90, 78, 88, 92]

plt.figure(figsize=(10, 6))
plt.bar(asignaturas, calificaciones, color='skyblue')
plt.title("Calificaciones por Asignatura", fontsize=16)
plt.xlabel("Asignaturas", fontsize=14)
plt.ylabel("Calificaciones", fontsize=14)
plt.ylim(0, 100)
plt.grid(axis='y', linestyle='--', alpha=0.9)
plt.show()

# %%
import matplotlib.pyplot as plt
sitios = ["Sitio A", "Sitio B", "Sitio C", "Sitio D", "Sitio E"]
tiempos = [1.2, 2.5, 0.9, 3.0, 1.8] 
plt.figure(figsize=(10, 6))
plt.bar(sitios, tiempos, color='lightgreen')
plt.title("Tiempos de Carga por Sitio", fontsize=16)
plt.xlabel("Sitios", fontsize=14)
plt.ylabel("Tiempo de Carga (s)", fontsize=14)
plt.ylim(0, 4)
plt.grid(axis='y', linestyle='--', alpha=0.9)
plt.show()

# %%
import matplotlib.pyplot as plt
horas_estudios = [1,2,3,4,5]
rendimiento = [ 50, 60, 70, 80, 90]
plt.figure(figsize=(10, 6))
plt.plot(horas_estudios, rendimiento, marker='o', color='purple')
plt.title("Rendimiento Académico vs Horas de Estudio", fontsize=16)
plt.xlabel("Horas de Estudio", fontsize=14)
plt.ylabel("Rendimiento Académico (%)", fontsize=14)
plt.xlim(0, 6)
plt.ylim(0, 100)
plt.grid(True, linestyle='--', alpha=0.9)
plt.show()

# %%
import matplotlib.pyplot as plt
salarios = {
    "Marquetin":[30000, 35000, 40000, 45000],
    "Ventas":[25000, 30000, 35000, 40000],
    "IT":[40000, 45000, 50000, 55000]
}
plt.figure(figsize=(10, 6))
plt.boxplot(salarios.values(), labels=salarios.keys())
plt.title("Distribución de Salarios por departarmento", fontsize=16)
plt.ylabel("Salario ($)", fontsize=14)
plt.grid(axis='y', linestyle='--', alpha=0.9)
plt.show()
# Out:
# /tmp/ipykernel_60418/2201980047.py:8: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(salarios.values(), labels=salarios.keys())
